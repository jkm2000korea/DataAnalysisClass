# %%
import KOSIS as ks

# %%
# 인허가 url
url = 'https://kosis.kr/openapi/Param/statisticsParameterData.do?method=getList&apiKey=MTExZTY3N2QyOWYxZjI2NDY5YzFmMjNhOWRiNjgxNzY=&itmId=13103871090T1+&objL1=ALL&objL2=13102871090B.0001+&objL3=13102871090C.0001+&objL4=13102871090D.0001+&objL5=&objL6=&objL7=&objL8=&format=json&jsonVD=Y&prdSe=M&startPrdDe=200701&endPrdDe=202305&orgId=116&tblId=DT_MLTM_1948'

# %%
#      pd.read_csv()
df = ks.get_data(url)
df
# Out:
#                        TBL_NM            ITM_NM_ENG         ITM_ID ORG_ID  \
# 0     주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 1     주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 2     주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 3     주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 4     주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# ...                       ...                   ...            ...    ...
# 4263  주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 4264  주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 4265  주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 4266  주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
# 4267  주택유형별 주택건설 인허가실적(월별 누계)  Construction permits  13103871090T1    116
#
#          UNIT_NM_ENG C1_OBJ_NM C2_OBJ_NM C3_OBJ_NM                 C4  \
# ...

# %%
df = ks.permission_preprocessing(df)

# %%
df
# Out:
# C1_NM   수도권_월   지방권_월
# 2007   302551  253241
# 2008   197580  173705
# 2009   255158  126629
# 2010   250218  136324
# 2011   272156  277438
# 2012   269290  317594
# 2013   192610  247506
# 2014   241889  273362
# 2015   408773  356555
# 2016   341162  384886
# 2017   321402  332039
# 2018   280097  274039
# 2019   272226  215749
# 2020   252301  205213
# 2021   291348  254064
# 2022   190833  330958
# 2023    60581   96953

# %%
ks.permission__graph(df)
